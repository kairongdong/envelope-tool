# %% [markdown]
# ## envelope tool
#
# CLI pipeline example. For an interactive version (upload a PDB, define domains in a browser UI, live 3D preview), run `python server.py` instead — see README.md.

# %%
# %%bash
# python envelope.py 3SOA.pdb domains.yaml -o 3soa_out --preview
